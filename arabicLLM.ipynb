# %% [markdown]
# <a href="https://colab.research.google.com/github/amkorwalid/nanoGPT/blob/main/arabicLLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# Fixed vocabulary size for all UTF-8 bytes (0-255)
vocab_size = 256

# Hyperparameters
embed_dim = 32
block_size = 16

# %%
class arabicTransformer(nn.Module):

  def __init__(self, vocab_size, embed_dim, block_size):
    super().__init__()


def forward(self, x):
    pass
